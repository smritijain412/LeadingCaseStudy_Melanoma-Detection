# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Defining the path for train and test images
data_dir_train = pathlib.Path("Skin cancer ISIC The International Skin Imaging Collaboration/train")
data_dir_test = pathlib.Path('Skin cancer ISIC The International Skin Imaging Collaboration/test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# # Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

train_ds = train_ds.map(lambda x, y: (x / 255.0, y))
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds  = tf.keras.utils.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds = val_ds.map(lambda x, y: (x / 255.0, y))
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# # Visualize the data
# Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt
for images, labels in train_ds.take(9):
    img = images[0]
    # Display the image
    plt.imshow(img.numpy()[:,:,1])
    plt.title(f"Class: {labels[0].numpy()}")
    plt.axis("off")
    plt.show()

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Create the model

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout,BatchNormalization,Activation,MaxPool2D
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import train_test_split

# %%
#now initialize Sequential layer 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=(img_height, img_width, 3)))
model.add(BatchNormalization())
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(strides=(2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(1024, activation='relu'))
model.add(Dense(9, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 178, 178, 16)      448
#
#  batch_normalization (BatchN  (None, 178, 178, 16)     64
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 176, 176, 16)      2320
#
#  batch_normalization_1 (Batc  (None, 176, 176, 16)     64
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 174, 174, 16)      2320
#
#  batch_normalization_2 (Batc  (None, 174, 174, 16)     64
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 172, 172, 16)      2320
#
#  batch_normalization_3 (Batc  (None, 172, 172, 16)     64
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 86, 86, 16)       0
#  )
#
#  flatten (Flatten)           (None, 118336)            0
#
#  dense (Dense)               (None, 512)               60588544
#
#  dense_1 (Dense)             (None, 1024)              525312
#
#  dense_2 (Dense)             (None, 9)                 9225
#
# =================================================================
# Total params: 61,130,745
# Trainable params: 61,130,617
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# # Compile the model

# %%
### Todo, choose an appropirate optimiser and loss function
from keras.optimizers import Adam
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/2
# 56/56 [==============================] - 185s 3s/step - loss: 15.1369 - accuracy: 0.2807 - val_loss: 28.6069 - val_accuracy: 0.0537
# Epoch 2/2
# 56/56 [==============================] - 178s 3s/step - loss: 2.9803 - accuracy: 0.3365 - val_loss: 103.0032 - val_accuracy: 0.0537

# %% [markdown]
# # Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Analysing the result

# %% [markdown]
# 1. provided data is simple and easy to learn hence it cause of overfitting.
# 2. this model is not able to learn noise and outliers.

# %% [markdown]
# # AGain build the model with dropout layer

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=(180,180,3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(9))
model.add(Activation('softmax'))

# %%
#compile the model

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#train the model
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/2
# 56/56 [==============================] - 254s 4s/step - loss: 48.9245 - accuracy: 0.3075 - val_loss: 11.2931 - val_accuracy: 0.1230
# Epoch 2/2
# 56/56 [==============================] - 263s 5s/step - loss: 6.8731 - accuracy: 0.2863 - val_loss: 73.7325 - val_accuracy: 0.1790

# %% [markdown]
# # Visualizing the result

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Analysis

# %% [markdown]
# 1. provided data is simple limited require more data to find the pattern .
# 2. if input  images are in rotated form model will not able to handle the input,hence images are straight-forward so for avoiding the overfitting we need to augment.

# %% [markdown]
# # Augmentation

# %%
# !pip install Augmentor
# Out:
# Requirement already satisfied: Augmentor in c:\users\smriti.jain.vaibhavglobal\anaconda3\lib\site-packages (0.2.12)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\smriti.jain.vaibhavglobal\anaconda3\lib\site-packages (from Augmentor) (9.0.1)
# Requirement already satisfied: tqdm>=4.9.0 in c:\users\smriti.jain.vaibhavglobal\anaconda3\lib\site-packages (from Augmentor) (4.64.0)
# Requirement already satisfied: numpy>=1.11.0 in c:\users\smriti.jain.vaibhavglobal\anaconda3\lib\site-packages (from Augmentor) (1.21.5)
# Requirement already satisfied: colorama in c:\users\smriti.jain.vaibhavglobal\anaconda3\lib\site-packages (from tqdm>=4.9.0->Augmentor) (0.4.6)

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 0

# %%
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new

# %% [markdown]
# # Build a augmented data set

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
# Augmentation parameters
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    rescale=1./255  # Normalize pixel values to be between 0 and 1
)

# %%
# Data preprocessing with ImageDataGenerator for augmentation
data_dir_train = 'Skin cancer ISIC The International Skin Imaging Collaboration/train'  # Update with your actual path
img_height, img_width = 180, 180
batch_size = 32

# %%
# Load and augment training dataset using ImageDataGenerator
train_ds = datagen.flow_from_directory(
    data_dir_train,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='sparse',  # Use 'sparse' for integer labels
    seed=123,
    subset="training"
    ,classes=class_names
)
# Out:
# Found 2239 images belonging to 9 classes.

# %%
# Load validation dataset without augmentation
val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir_train,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# Model definition
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=(img_height, img_width, 3)))
model.add(BatchNormalization())
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(strides=(2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(1024, activation='relu'))
model.add(Dense(9, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
epochs = 20
history = model.fit(
    train_ds,
    epochs=epochs
)
# Out:
# Epoch 1/2
# 57/70 [=======================>......] - ETA: 44s - loss: 16.8518 - accuracy: 0.2830

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
